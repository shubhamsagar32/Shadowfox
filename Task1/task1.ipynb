# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('HousingData.csv')

# %%
dataset
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
a=np.shape(dataset)

# %%
a
# Out:
# (506, 14)

# %%
print(dataset.describe())
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
dataset.fillna(dataset["CRIM"].mean(),inplace=True)
dataset.fillna(dataset["ZN"].mean(),inplace=True)
dataset.fillna(dataset["INDUS"].mean(),inplace=True)
dataset.fillna(dataset["CHAS"].mean(),inplace=True)
dataset.fillna(dataset["AGE"].mean(),inplace=True)
dataset.fillna(dataset["LSTAT"].mean(),inplace=True)

dataset
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.200000  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.900000  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.100000  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.800000  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.200000  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...        ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.100000  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.700000  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.000000  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.300000  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   3.611874  2.5050    1  273
#
#      PTRATIO       B     LSTAT  MEDV
# ...

# %%
plt.figure(figsize=(22,8))
plt.scatter(dataset.index,dataset["MEDV"],color="red",lw=3)
plt.plot(dataset.index,dataset["MEDV"])
plt.title("Median value of homes (in $1000)")
plt.grid(True)
plt.show()

# %%
import seaborn as sns
fig, ax1 = plt.subplots(7,2, figsize=(20,25))
k = 0
columns = list(dataset.columns)
for i in range(7):
    for j in range(2):
            sns.histplot(dataset[columns[k]], ax = ax1[i][j], color = 'green')
            ax1[i][j].grid(True)
            k += 1
plt.show()

# %%
def log_transform(col):
    return np.log(col[0])

dataset["DIS"]=dataset[["DIS"]].apply(log_transform, axis=1)

sns.histplot(dataset["DIS"], color = 'green')
plt.grid(True)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

X=dataset.iloc[:,0:13]
Y=dataset.iloc[:,13]

print("Unscaled Data: \n")
display(X)  
scaler = StandardScaler()
X = scaler.fit_transform(X)
print("Scaled Data: \n")
display(X)
# Out:
# Unscaled Data:
#         CRIM    ZN  INDUS  CHAS    NOX     RM        AGE       DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.200000  1.408545    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.900000  1.602836    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.100000  1.602836    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.800000  1.802073    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.200000  1.802073    3  222
# ..       ...   ...    ...   ...    ...    ...        ...       ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.100000  0.907694    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.700000  0.827460    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.000000  0.773574    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.300000  0.870833    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   3.611874  0.918289    1  273
#
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.model_selection import GridSearchCV

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,random_state=94)

# %%
import xgboost as xgb
xgbr = xgb.XGBRegressor(objective='reg:squarederror',
                        random_state=50,
                        max_depth=6,
                        learning_rate = 0.08,
                        n_estimators = 500,
                        colsample_bylevel = 0.4,
                        reg_alpha = 1,
                        subsample = 1,
                       )

xgbr.fit(X_train,Y_train)
Y_pred = xgbr.predict(X_test)
mse=mean_squared_error(Y_test, Y_pred)
score=r2_score(Y_test,Y_pred)
print("Root Mean Square Error: %.2f" % (mse**(0.5)))
print("Accuracy: {} %".format(round((score*100),2)))
# Out:
# Root Mean Square Error: 2.86
# Accuracy: 90.83 %

# %%
a1=dataset.iloc[0,:].values.reshape(1, -1)
a1
# Out:
# array([[6.32000000e-03, 1.80000000e+01, 2.31000000e+00, 0.00000000e+00,
#         5.38000000e-01, 6.57500000e+00, 6.52000000e+01, 1.40854497e+00,
#         1.00000000e+00, 2.96000000e+02, 1.53000000e+01, 3.96900000e+02,
#         4.98000000e+00, 2.40000000e+01]])

# %%
import warnings
warnings.filterwarnings("ignore")
a2=scaler.transform(dataset.iloc[0,0:13].values.reshape(1, -1))
a2
# Out:
# array([[-0.42232846,  0.30891636, -1.23792803, -0.28604448, -0.14421743,
#          0.41367189, -0.0249442 ,  0.40910428, -0.98284286, -0.66660821,
#         -1.45900038,  0.44105193, -1.02058242]])

# %%
a3=xgbr.predict(scaler.transform(dataset.iloc[0,0:13].values.reshape(1, -1)))
a3
# Out:
# array([24.065989], dtype=float32)

# %%
#regressor_model=k nearest neighbors
from sklearn.neighbors import KNeighborsRegressor
results={}
knn_regressor = KNeighborsRegressor()
knn_regressor.fit(X_train, Y_train)
y_pred_knn = knn_regressor.predict(X_test)
mse_knn = mean_squared_error(Y_test, y_pred_knn)
r2_knn = r2_score(Y_test, y_pred_knn)
results['K-Nearest Neighbors'] = {'MSE': mse_knn, 'R2': r2_knn}

# %%
results
# Out:
# {'K-Nearest Neighbors': {'MSE': 22.66901176470588, 'R2': 0.7460572130470091}}
